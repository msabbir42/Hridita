# %% [markdown]
# # Import Library

# %%
# To run the codes, one will need to install the following libraries.

library(data.table)
library(dplyr)
library(lubridate)
library(cosinor2)
library(car)
library(olsrr)
library(writexl)
library(readxl)
library(ggplot2)
library(stringr)

# %% [markdown]
# # Extracting rhythms

# %%
date_time = "%Y-%m-%dT%H:%M:%OS"
period_in_hour <- 24
data_name = 'HeartRatePPG'

loc_save_file = 'C:/Users/wyd2hu/OneDrive - University of Virginia/Hridita/Rhythms/Findings/'
ds_loc_list <- c('C:/Users/wyd2hu/S2He/AudData/Tiles18/fitbit/heart-rate/') # 'C:/Users/wyd2hu/S2He/AudData/Tiles19/tiles-phase2-opendataset/fitbit/heart-rate/'

dataset = ''

for (loc_root_data in ds_loc_list)
{
    n_counter_less_than_7 = 0
    not_more_than_8_days = 0
    all_data_same = 0
    
    if (str_detect(loc_root_data, 'Tiles19'))
    {
        dataset = 'Tiles19'
    }
    else if (str_detect(loc_root_data, 'Tiles18'))
    {
        dataset = 'Tiles18'
    }

    print(paste0('DS ', dataset))
    saving_file <-  paste0(loc_save_file, dataset, '_', data_name,'.xlsx')
    rhythm_df_sheets <- list()

    # Checking whether rhythm is already extracted
    if (file.exists(saving_file))
    {
      saved_rhythm_sheets_by_data = excel_sheets(path=saving_file)
      for (rhythm_sheet in saved_rhythm_sheets_by_data)
      {
          rhythm_df_sheets[[rhythm_sheet]] <- read_excel(path = saving_file, sheet = rhythm_sheet)
      }
    }
    else
    {
        saved_rhythm_sheets_by_data = c()
    }
    
    for(file in list.files(loc_root_data, pattern = ".csv.gz"))
    {
        # if (grepl('16812063-e5df-4657-b86c-5b55a0c9ffe6', file, fixed=TRUE))
        # {
        print(paste0(dataset, ' ',  file))

        print(length(grep(str_sub(gsub('.csv.gz', '', file), 1, 25), saved_rhythm_sheets_by_data)))
        if (length(grep(str_sub(gsub('.csv.gz', '', file), 1, 25), saved_rhythm_sheets_by_data)) == 0)
        {
            df = fread(paste0(loc_root_data, "//", file))
            df$Timestamp <- as.POSIXct(df$Timestamp , format = "%Y-%m-%dT%H:%M:%OS")
            # df$Timestamp <- format(strptime(df$Timestamp, format = "%Y-%m-%d %H:%M:%OS"), format = "%Y-%m-%d %H:%M:%OS")
            df$time_float <- format(strptime(df$Timestamp, format = "%Y-%m-%d %H:%M:%OS"), format = "%H.%M")
            df$time_float <- as.numeric(df$time_float)
            
            df <- na.omit(df[, , drop = FALSE])
            if (nrow(df) > 1) # ensuring that there remains at least 1 value after dropping the nan values
            {
                first_row <- head(df, 1)
                last_row <- tail(df, 1)
                # print(last_row)
            
                start_date = first_row$Timestamp[[1]]
                
                d_days = as.integer(difftime(last_row$Timestamp[[1]] , start_date, units = "days"))
                n_times_rhythm_cal = as.integer(d_days/2)
        
                if (n_times_rhythm_cal > 4) # We need at least 7 days (2 days for rhythm. so, if we take 7 days, we will have 4 data points which I assume can be the minimum for estimating elbow) 
                    # to find the baseline rhythm to detect changes
                {
                    df_cosinor <- data.frame(matrix(ncol = 10, nrow = 1))
                    colnames(df_cosinor) <- c('N_Times', 'data_name', 'p_id', 'mesor', 'amplitude', 'correct_acrophase',
                                              'rhythm_detect_F_ratio', 'rhythm_detect_P', 'dominant_period', 'coef_determination')
                    # print(paste0("N times rhythm calculation ", n_times_rhythm_cal))
                    for(counter in 1:n_times_rhythm_cal)
                    {
                            # print(paste0(counter, start_date))
                            date_time <- as.POSIXct(start_date, format = "%Y-%m-%d %H:%M:%OS")
                            end_date = format(date_time + days(2), format = "%Y-%m-%d %H:%M:%OS")
                        
                            df_subset <- subset(df, subset=c((Timestamp >= start_date) & (Timestamp < end_date)))  ## the end date is going to be the start date in the next iteration
    
                            if (nrow(df_subset) > 7) # sample size must be greater than 7 to calculate the normality as per the req. of ols_test_normality
                            {
                                df_subset$time_in_24 = ifelse(df_subset$time_float < 1, df_subset$time_float+24, df_subset$time_float)
                                colnames(df_subset)[colnames(df_subset) == 'HeartRatePPG'] <- 'Data'

                                if (length(unique(df_subset$Data)) > 1)
                                {
                                        if (nrow(df_subset) > 5000) # since more than 5000 values, ols_test_normality() does not work
                                        {
                                            my_model <- lm(df_subset$Data[0:5000] ~ df_subset$time_in_24[0:5000])
                                        }
                                        else
                                        {
                                            my_model <- lm(df_subset$Data ~ df_subset$time_in_24)
                                        }
        
                                        kolmogorv_p <- ols_test_normality(my_model)[[1]][2] # [[1]][2] presents p value of Kolmogorov-Smirnov as I checked manually by this dataset and also by cars dataset
                                        if (kolmogorv_p < 0.05) # Rejected null hypothesis. So, data is not normally distributed :).
                                        {
                                            log_data = log(df_subset$Data + 1)
                                        }
                                        else # We do not have enough evidence to reject null hypothesis and data is normally distributed
                                        {
                                            log_data = df_subset$Data
                                        }
                                    
                                        fit <- cosinor.lm(log_data ~ time(time_in_24), data = df_subset, period = period_in_hour)
                                    
                                        s_fit <- summary(fit)
                                        mesor <- s_fit[[1]]$estimate[1] # Transformed coef: s_fit[[1]]; estimate column; s_fit[[1]]['estimate'][[1]] returns the values in the estimate column; [1] value is the intercept as I found through investigation
                                        ampli <- s_fit[[1]]$estimate[2]
                                        corr_acro <- correct.acrophase(fit)
                                        df_detect <- as.data.frame(cosinor.detect(fit))
                                    
                                        output <- periodogram(data = t(log_data), time = df_subset$time_in_24, periods=1:24)
                                        dominant_period <- which.max(unlist(c(output)$data))  # I checked it manually. MAJOR REMINDER: If you use the all periods (which is by default) given through (sheet_data$time_in_24), this will not work since the number of periods will be more 24 and indecies will not present the actual index
                            
                                        row_number = nrow(df_cosinor) + 1
                                        df_cosinor[row_number, ] <- c(counter, data_name, gsub('-', '', gsub(".csv.gz", '', file)), 
                                                                      mesor, ampli, corr_acro,
                                                                      df_detect$F, df_detect$p, dominant_period[[1]],
                                                                      unlist(c(output)$data)[dominant_period][[1]])
                                    
                                        # output <- output + scale_color_manual(values=c('Yellow')) + theme(
                                        #     axis.text.x = element_text(angle=90, colour="black", size=18, family='Times New Roman'),
                                        #     axis.text.y = element_text(colour="black", size=18, family='Times New Roman'),
                                        #     axis.title.x = element_text(colour= 'black', size=18, family='Times New Roman'),
                                        #     axis.title.y = element_text(colour = 'black', size=18, family='Times New Roman'),
                                        #     legend.title = element_blank(),
                                        #     panel.grid.major.x=element_line(colour="#CCDDEE"),
                                        #     legend.text = element_text(colour='black', family = 'Times New Roman', size=22),
                                        #     panel.grid = element_blank(), axis.ticks.y = element_line(),
                                        #     panel.background = element_rect(fill = 'white', colour = 'white'),
                                        #     plot.background = element_rect(fill = 'white', colour = 'white'))
                                        # # suppressMessages(ggsave(output, file=figure_to_saved, dpi=700))
                                        rhythm_df_sheets[[str_sub(gsub('.csv.gz', '', file), 1, 25)]] <- df_cosinor
                                }
                                else
                                {
                                    all_data_same = all_data_same + 1
                                }
                            }
                            else
                            {
                                n_counter_less_than_7 = n_counter_less_than_7 + 1
                            }
                            start_date = end_date
                    }
                }
                else
                {
                    not_more_than_8_days = not_more_than_8_days + 1
                    print("Less than or equal to 8 days data 😒😒")
                    print(file)
                }
            }
            else
            {
                print("Empty dataframe 😒😒")
                print(file)
            }
        }else
        {
            print(paste0('Exists', file))
        }
        # }
    }
    print(saving_file)
    write_xlsx(rhythm_df_sheets, saving_file) # REMINDER: if you use personalized dominant period, change period_in_hour
    print(n_counter_less_than_7)
    print(all_data_same)
    print(not_more_than_8_days)
    print('\n\n1 Dataset Done\n\n')
}
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# [1] "DS Tiles18"
# [1] "Tiles18 02581754-36cd-4b23-85ea-bf995c6dec83.csv.gz"
# [1] 1
# [1] "Exists02581754-36cd-4b23-85ea-bf995c6dec83.csv.gz"
# [1] "Tiles18 0271c478-a56a-4c09-ab91-9743184dd71b.csv.gz"
# [1] 1
# [1] "Exists0271c478-a56a-4c09-ab91-9743184dd71b.csv.gz"
# [1] "Tiles18 02b7a595-6508-46bd-8239-6deb433d6290.csv.gz"
# [1] 1
# [1] "Exists02b7a595-6508-46bd-8239-6deb433d6290.csv.gz"
# [1] "Tiles18 05dedb61-63bc-44e3-8e28-a5d32d91f7e9.csv.gz"
# [1] 1
# [1] "Exists05dedb61-63bc-44e3-8e28-a5d32d91f7e9.csv.gz"
# [1] "Tiles18 06b33ec4-706d-462f-a681-05491be38eb3.csv.gz"
# [1] 1
# [1] "Exists06b33ec4-706d-462f-a681-05491be38eb3.csv.gz"
# [1] "Tiles18 0a85fd46-fada-434c-9f7a-08b81f9ed8e7.csv.gz"
# [1] 1
# [1] "Exists0a85fd46-fada-434c-9f7a-08b81f9ed8e7.csv.gz"
# [1] "Tiles18 0adb7679-9d26-46e7-a134-11da293910f3.csv.gz"
# [1] 1
# [1] "Exists0adb7679-9d26-46e7-a134-11da293910f3.csv.gz"
# [1] "Tiles18 0b45e9c1-eba5-46d3-b0a4-cdb5aa4dc736.csv.gz"
# [1] 1
# [1] "Exists0b45e9c1-eba5-46d3-b0a4-cdb5aa4dc736.csv.gz"
# [1] "Tiles18 0bf54591-e0ac-47ba-9b43-31ff54dfcee8.csv.gz"
# [1] "Tiles18 481aca07-ac33-4f38-98b7-3405dc3d60dc.csv.gz"
# [1] 1
# [1] "Exists481aca07-ac33-4f38-98b7-3405dc3d60dc.csv.gz"
# [1] "Tiles18 49a44e13-111a-4f8d-b4ea-5d3476cb83a3.csv.gz"
# [1] 1
# [1] "Exists49a44e13-111a-4f8d-b4ea-5d3476cb83a3.csv.gz"
# [1] "Tiles18 4b5a5d57-0ad9-49fc-913f-d9e33b90b159.csv.gz"
# [1] 1
# [1] "Exists4b5a5d57-0ad9-49fc-913f-d9e33b90b159.csv.gz"
# [1] "Tiles18 4b8d9e5c-1e51-4a1d-81c9-b3911f623c08.csv.gz"
# [1] 1
# [1] "Exists4b8d9e5c-1e51-4a1d-81c9-b3911f623c08.csv.gz"
# [1] "Tiles18 4e471779-ecbc-4b5a-b6b0-fcbfc9479faa.csv.gz"
# [1] 1
# [1] "Exists4e471779-ecbc-4b5a-b6b0-fcbfc9479faa.csv.gz"
# [1] "Tiles18 4e541136-0db1-4749-b4c1-8dc03df3d4a5.csv.gz"
# [1] 1
# [1] "Exists4e541136-0db1-4749-b4c1-8dc03df3d4a5.csv.gz"
# [1] "Tiles18 4ea2ae1d-8d6b-4c7f-ac60-27fd6e5b67b0.csv.gz"
# [1] 1
# [1] "Exists4ea2ae1d-8d6b-4c7f-ac60-27fd6e5b67b0.csv.gz"
# [1] "Tiles18 4ed3225f-868e-43c6-9e57-0329d9ff9e9d.csv.gz"
# [1] 1
# [1] "Exists4ed3225f-868e-43c6-9e57-0329d9ff9e9d.csv.gz"
# [1] "Tiles18 5072f60b-88da-4fd2-8339-f2c45496ffa4.csv.gz"
# [1] 1
# [1] "Exists5072f60b-88da-4fd2-8339-f2c45496ffa4.csv.gz"
# [1] "Tiles18 51adda7d-b627-48e0-98be-72386fc84661.csv.gz"
# [1] 1
# [1] "Exists51adda7d-b627-48e0-98be-72386fc84661.csv.gz"
# [1] "Tiles18 5375b0e9-db92-4189-801a-1e9dbe1d9f61.csv.gz"
# [1] 1
# [1] "Exists5375b0e9-db92-4189-801a-1e9dbe1d9f61.csv.gz"
# [1] "Tiles18 5bb7f10e-ea7d-4af3-adae-c0d92e8a700d.csv.gz"
# [1] 1
# [1] "Exists5bb7f10e-ea7d-4af3-adae-c0d92e8a700d.csv.gz"
# [1] "Tiles18 5c7c51c5-8bd6-4997-92c1-ce4c5eda45e6.csv.gz"
# [1] 1
# [1] "Exists5c7c51c5-8bd6-4997-92c1-ce4c5eda45e6.csv.gz"
# [1] "Tiles18 5dc874cc-0b53-449b-bfa9-57fb665f388b.csv.gz"
# [1] 1
# [1] "Exists5dc874cc-0b53-449b-bfa9-57fb665f388b.csv.gz"
# [1] "Tiles18 62e88542-8d2e-4148-bd5f-2a3b47cdac44.csv.gz"
# [1] 0
# Warning message in `[.data.table`(df, , , drop = FALSE):
# "i and j are both missing so ignoring the other arguments. This warning will be upgraded to error in future."
# [1] "Less than or equal to 8 days data <U+0001F612><U+0001F612>"
# [1] 1
# [1] "Exists71931795-5de7-4863-ae0c-3fb5edb5f9e0.csv.gz"
# [1] "Tiles18 757d34ef-7f1b-41f5-b072-ea4a4f336b80.csv.gz"
# [1] 1
# [1] "Exists757d34ef-7f1b-41f5-b072-ea4a4f336b80.csv.gz"
# [1] "Tiles18 75c633d4-6ade-471e-983a-aadc07d9383c.csv.gz"
# [1] 1
# [1] "Exists75c633d4-6ade-471e-983a-aadc07d9383c.csv.gz"
# [1] "Tiles18 7607c6de-7244-4ba1-ab7c-5c4c4d7151ad.csv.gz"
# [1] 1
# [1] "Exists7607c6de-7244-4ba1-ab7c-5c4c4d7151ad.csv.gz"
# [1] "Tiles18 77dfe9b8-5f40-49a6-ba09-706198bb8a48.csv.gz"
# [1] 1
# [1] "Exists77dfe9b8-5f40-49a6-ba09-706198bb8a48.csv.gz"
# [1] "Tiles18 787b23f7-f912-43c4-8caf-7a16c57e0256.csv.gz"
# [1] 1
# [1] "Exists787b23f7-f912-43c4-8caf-7a16c57e0256.csv.gz"
# [1] "Tiles18 7b0d87b0-c099-44eb-9815-67d51d73db9a.csv.gz"
# [1] 1
# [1] "Exists7b0d87b0-c099-44eb-9815-67d51d73db9a.csv.gz"
# [1] "Tiles18 7b497dbd-18ec-4d3c-88dd-e9f1d67fb493.csv.gz"
# [1] 1
# [1] "Exists7b497dbd-18ec-4d3c-88dd-e9f1d67fb493.csv.gz"
# [1] "Tiles18 7bb5eee8-70d6-4b16-990a-a62cf827170a.csv.gz"
# [1] 1
# [1] "Exists7bb5eee8-70d6-4b16-990a-a62cf827170a.csv.gz"
# [1] "Tiles18 7c34bf1b-3b8b-45cd-ae97-26f2eafe97dd.csv.gz"
# [1] 1
# [1] "Exists7c34bf1b-3b8b-45cd-ae97-26f2eafe97dd.csv.gz"
# [1] "Tiles18 7c885f26-7923-41a3-847e-c971eafee8d4.csv.gz"
# [1] 1
# [1] "Exists7c885f26-7923-41a3-847e-c971eafee8d4.csv.gz"
# [1] "Tiles18 7e6a98f1-73c3-4023-9bbd-acf2b70d04b5.csv.gz"
# [1] 1
# [1] "Exists7e6a98f1-73c3-4023-9bbd-acf2b70d04b5.csv.gz"
# [1] "Tiles18 7e883e52-65af-4edb-9d55-a72ba5f03287.csv.gz"
# [1] 1
# [1] "Exists7e883e52-65af-4edb-9d55-a72ba5f03287.csv.gz"
# [1] "Tiles18 803be457-cee4-4f3f-9540-ff574c57c697.csv.gz"
# [1] 0
# Warning message in `[.data.table`(df, , , drop = FALSE):
# "i and j are both missing so ignoring the other arguments. This warning will be upgraded to error in future."
# [1] "Less than or equal to 8 days data <U+0001F612><U+0001F612>"
# [1] "803be457-cee4-4f3f-9540-ff574c57c697.csv.gz"
# [1] "Tiles18 8307ff6e-f582-49b0-81cc-39fe9966d097.csv.gz"
# [1] 1
# [1] "Exists8307ff6e-f582-49b0-81cc-39fe9966d097.csv.gz"
# [1] "Tiles18 8323bb7d-6b8d-4dea-82d6-08944e6da3a9.csv.gz"
# [1] 1
# [1] "Tiles18 a7633bbc-3145-4bba-b86b-cef5e4ae3273.csv.gz"
# [1] 1
# [1] "Existsa7633bbc-3145-4bba-b86b-cef5e4ae3273.csv.gz"
# [1] "Tiles18 a7db3311-aa07-4580-b552-73c18657c803.csv.gz"
# [1] 1
# [1] "Existsa7db3311-aa07-4580-b552-73c18657c803.csv.gz"
# [1] "Tiles18 a81eedd1-fb39-4763-bf76-a0472f78ce9f.csv.gz"
# [1] 1
# [1] "Existsa81eedd1-fb39-4763-bf76-a0472f78ce9f.csv.gz"
# [1] "Tiles18 a8800ef0-619c-4a3c-af5b-df1d2a3a6f71.csv.gz"
# [1] 1
# [1] "Existsa8800ef0-619c-4a3c-af5b-df1d2a3a6f71.csv.gz"
# [1] "Tiles18 a9dfbe4d-4076-48c7-a72b-342fe4c12514.csv.gz"
# [1] 1
# [1] "Existsa9dfbe4d-4076-48c7-a72b-342fe4c12514.csv.gz"
# [1] "Tiles18 aa8d1b7a-14c6-4490-a57b-d3893ac28b03.csv.gz"
# [1] 1
# [1] "Existsaa8d1b7a-14c6-4490-a57b-d3893ac28b03.csv.gz"
# [1] "Tiles18 aae509f5-ab41-43a0-85c2-5dfad0ed520a.csv.gz"
# [1] 1
# [1] "Existsaae509f5-ab41-43a0-85c2-5dfad0ed520a.csv.gz"
# [1] "Tiles18 ab23fe51-7249-4c81-bec3-451b6ab1d140.csv.gz"
# [1] 1
# [1] "Existsab23fe51-7249-4c81-bec3-451b6ab1d140.csv.gz"
# [1] "Tiles18 adc70680-fedc-481e-be34-32c6630ab3cd.csv.gz"
# [1] 1
# [1] "Existsadc70680-fedc-481e-be34-32c6630ab3cd.csv.gz"
# [1] "Tiles18 aea11c01-40d9-479e-aa27-0b8bf464de52.csv.gz"
# [1] 1
# [1] "Existsaea11c01-40d9-479e-aa27-0b8bf464de52.csv.gz"
# [1] "Tiles18 aef21a29-6b16-4d49-9a07-96c12fcd5698.csv.gz"
# [1] 1
# [1] "Existsaef21a29-6b16-4d49-9a07-96c12fcd5698.csv.gz"
# [1] "Tiles18 b24987c0-4530-45b4-8dc1-c42c4e0cd7ad.csv.gz"
# [1] 1
# [1] "Existsb24987c0-4530-45b4-8dc1-c42c4e0cd7ad.csv.gz"
# [1] "Tiles18 b318de0d-0b0a-4ba8-a7be-9fcf7b9d8c67.csv.gz"
# [1] 1
# [1] "Existsb318de0d-0b0a-4ba8-a7be-9fcf7b9d8c67.csv.gz"
# [1] "Tiles18 b31b6e69-0384-4d5d-8eac-5f512862690b.csv.gz"
# [1] 1
# [1] "Existsb31b6e69-0384-4d5d-8eac-5f512862690b.csv.gz"
# [1] "Tiles18 ba240e43-900d-4477-8718-b9487ed24d7d.csv.gz"
# [1] 1
# [1] "Existsba240e43-900d-4477-8718-b9487ed24d7d.csv.gz"
# [1] "Tiles18 bdb64352-b982-4aab-8d98-3c56c5a6441f.csv.gz"
# [1] 1
# [1] "Existsbdb64352-b982-4aab-8d98-3c56c5a6441f.csv.gz"
# [1] "Existsd28b2c23-1da4-4b64-be94-df4aa6121559.csv.gz"
# [1] "Tiles18 d62a5591-4c0c-4c95-9187-faa64b95f9fc.csv.gz"
# [1] 1
# [1] "Existsd62a5591-4c0c-4c95-9187-faa64b95f9fc.csv.gz"
# [1] "Tiles18 dafdc3d9-e474-4556-8958-204f68ad5ebc.csv.gz"
# [1] 1
# [1] "Existsdafdc3d9-e474-4556-8958-204f68ad5ebc.csv.gz"
# [1] "Tiles18 db082772-c8cc-4df4-a647-6a80ee2db9ce.csv.gz"
# [1] 1
# [1] "Existsdb082772-c8cc-4df4-a647-6a80ee2db9ce.csv.gz"
# [1] "Tiles18 db2bffd9-c5b5-4fed-9d55-09a087ce0e6e.csv.gz"
# [1] 1
# [1] "Existsdb2bffd9-c5b5-4fed-9d55-09a087ce0e6e.csv.gz"
# [1] "Tiles18 dc65ee54-ad64-4cce-8d0a-878033ff02d7.csv.gz"
# [1] 1
# [1] "Existsdc65ee54-ad64-4cce-8d0a-878033ff02d7.csv.gz"
# [1] "Tiles18 dcc3e9ff-9c05-4e17-9798-fd5114be77a9.csv.gz"
# [1] 1
# [1] "Existsdcc3e9ff-9c05-4e17-9798-fd5114be77a9.csv.gz"
# [1] "Tiles18 deb03e25-16f1-403a-8152-891f50b50ae4.csv.gz"
# [1] 1
# [1] "Existsdeb03e25-16f1-403a-8152-891f50b50ae4.csv.gz"
# [1] "Tiles18 df3a6b7a-7e27-4003-beea-2cb5cf08da83.csv.gz"
# [1] 1
# [1] "Existsdf3a6b7a-7e27-4003-beea-2cb5cf08da83.csv.gz"
# [1] "Tiles18 e027002a-cf96-4132-a4ac-2003e945258d.csv.gz"
# [1] 1
# [1] "Existse027002a-cf96-4132-a4ac-2003e945258d.csv.gz"
# [1] "Tiles18 e05bec91-93e2-4b23-9d4f-ae79dade8451.csv.gz"
# [1] 1
# [1] "Existse05bec91-93e2-4b23-9d4f-ae79dade8451.csv.gz"
# [1] "Tiles18 e31e0dfd-b00c-43e4-a1ea-f5110bf01c1c.csv.gz"
# [1] 1
# [1] "Existse31e0dfd-b00c-43e4-a1ea-f5110bf01c1c.csv.gz"
# [1] "Tiles18 e3e5e4aa-5950-4f1f-915c-c67598965b03.csv.gz"
# [1] 1
# [1] "Existse3e5e4aa-5950-4f1f-915c-c67598965b03.csv.gz"
# [1] "Tiles18 e5be76f8-6461-481b-834e-b44f8f880273.csv.gz"
# [1] 1
# [1] "Existse5be76f8-6461-481b-834e-b44f8f880273.csv.gz"
# [1] "Tiles18 e6081755-d7f3-4c26-ab40-0709b8ad41ef.csv.gz"
# [1] 1
# [1] "Existse6081755-d7f3-4c26-ab40-0709b8ad41ef.csv.gz"
# [1] "Tiles18 e8606fff-0ac6-4832-bb79-323b89ebcf2e.csv.gz"
# [1] 1
# [1] "Existse8606fff-0ac6-4832-bb79-323b89ebcf2e.csv.gz"
# [1] "Tiles18 e89b1ea7-a2ea-4f2f-ae5a-9a9d29af8639.csv.gz"
# [1] 1
# [1] "Existse89b1ea7-a2ea-4f2f-ae5a-9a9d29af8639.csv.gz"
# [1] 1
# [1] "Existsfae38580-1e2d-4491-9de5-7b75703ba4ce.csv.gz"
# [1] "Tiles18 fb3a4dd7-3cb5-438e-a75d-244d1aec4790.csv.gz"
# [1] 1
# [1] "Existsfb3a4dd7-3cb5-438e-a75d-244d1aec4790.csv.gz"
# [1] "Tiles18 fcb14a4c-1ffa-4315-872a-a38833459885.csv.gz"
# [1] 1
# [1] "Existsfcb14a4c-1ffa-4315-872a-a38833459885.csv.gz"
# [1] "Tiles18 fd79ab30-1199-4619-adbd-577d715d86ce.csv.gz"
# [1] 1
# [1] "Existsfd79ab30-1199-4619-adbd-577d715d86ce.csv.gz"
# [1] "Tiles18 fdbd8c07-720c-4ae5-a3d8-aad56b54688c.csv.gz"
# [1] 1
# [1] "Existsfdbd8c07-720c-4ae5-a3d8-aad56b54688c.csv.gz"
# [1] "C:/Users/wyd2hu/OneDrive - University of Virginia/Hridita/Rhythms/Findings/Tiles18_HeartRatePPG.xlsx"
# [1] 0
# [1] 0
# [1] 2
# [1] "\n\n1 Dataset Done\n\n"

# %%
test_list = list(1, 1, 1, 1, 1)
print(length(unique(test_list)))
# Out:
# [1] 1

# %%
loc_save_file = 'C:/Users/wyd2hu/S2He/'
saving_file <-  paste0(loc_save_file, dataset, '_', data_name,'.xlsx')
print(saving_file)
write_xlsx(new_rhythm_df_sheets, saving_file) # REMINDER: if you use personalized dominant period, change period_in_hour
# Out:
# [1] "C:/Users/wyd2hu/S2He/Tiles18_HeartRatePPG.xlsx"

# %%
# new_rhythm_df_sheets = list()
for (p_id in names(new_rhythm_df_sheets))
{
    print(str_sub(p_id, 1, 20))
    new_rhythm_df_sheets[[str_sub(p_id, 1, 15)]] <- rhythm_df_sheets[[p_id]]
}
# Out:
# Error in eval(expr, envir, enclos): object 'new_rhythm_df_sheets' not found
# Traceback:

# %%
write_xlsx(rhythm_df_sheets, saving_file) # REMINDER: if you use personalized dominant period, change period_in_hour
# Out:
# Warning message in write_xlsx(rhythm_df_sheets, saving_file):
# "Truncating sheet name(s) to 31 characters"
# Error: Error in writexl: failed to create workbook
# Traceback:
#
# 1. write_xlsx(rhythm_df_sheets, saving_file)

# %%
saving_file <-  paste0(loc_save_file, dataset, '_', data_name,'.xlsx')

if (file.exists(saving_file))
{
  saved_rhythm_sheets_by_data = excel_sheets(path=saving_file)
  for (rhythm_sheet in saved_rhythm_sheets_by_data)
  {
      rhythm_df_sheets[[rhythm_sheet]] <- read_excel(path = saving_file, sheet = rhythm_sheet)
  }
}else
{
    saved_rhythm_sheets_by_data = c()
}
# Out:
# [1] "19329467-7c45-406b-b487-4dfd0"
# [1] "1db1552c-5703-4400-a38e-8d3ba"
# [1] "1f448103-5ef3-40e5-9131-a22cb"
# [1] "21ab94d3-a40e-4c25-8410-ef07e"
# [1] "240b79e1-6f67-4e8d-b8ca-3500c"
# [1] "242dc7a7-083c-4b44-b65c-30e09"
# [1] "28463428-d7ba-42c0-b40d-481fd"
# [1] "2a62ecbe-e948-439f-a6a4-19374"
# [1] "338d4215-9d6e-40b7-89bd-1467b"
# [1] "3cbb9484-f795-4881-867e-724f0"
# [1] "42355c53-f0ce-41f7-8d50-91ccd"
# [1] "42a68d6a-3778-41cb-929b-6da08"
# [1] "490461f8-3d56-4c88-8a4a-8ceb8"
# [1] "4d2b899d-c221-4657-b74c-767e3"
# [1] "4f91d234-b726-497b-aa81-df6b6"
# [1] "50d1e47e-8b6c-47af-b5cb-e8742"
# [1] "66c57f1a-de1f-415a-b79a-5701a"
# [1] "6dce952d-f46c-408f-a8f1-ce636"
# [1] "712a00af-4e8e-4236-b941-d6f9b"
# [1] "7c78cdc7-915b-4883-9ca2-04c8b"
# [1] "89209220-8ecf-4cd6-a9a4-aa713"
# [1] "8a2e94a7-9dc3-4e67-a6d2-012da"
# [1] "8dde8abc-014e-480a-9a07-c113c"
# [1] "96d9d951-869c-4488-a649-c2ab6"
# [1] "9885f7a8-e7d1-4b1c-8f85-3a4d0"
# [1] "9cc29340-a44f-4d00-bac8-634cf"
# [1] "a09fb0df-51ca-4fd9-9717-b7b36"
# [1] "a34b4f63-6a7d-4a5f-bf11-1c110"
# [1] "a3d02140-099f-43ae-946f-aa0b4"
# [1] "a3df0da8-33d9-463b-babd-5bbb0"
# [1] "a4c6e096-1e36-4456-94bc-2adff"
# [1] "c6a9415c-2d7c-4cef-9222-79de6"
# [1] "ce871d21-38ba-4875-882f-00b52"
# [1] "cefa520e-b1f2-4db0-a155-e8d92"
# [1] "d34aefad-d744-4462-8a77-c9170"
# [1] "d5de89b1-c44d-4c69-8952-64d59"
# [1] "d8771070-e08f-4c3c-a462-00fbd"
# [1] "dd25c5e6-d287-40b6-ae4b-73c6c"
# [1] "dd291cc4-035a-4bf0-8ca6-fbb28"
# [1] "df7e60c4-b570-44b4-b613-eca36"
# [1] "e7dc6884-cbdd-4df5-8df6-017bc"
# [1] "e81ae973-f115-4acb-9452-cc07a"
# [1] "ebf4f216-2e6a-4dd2-9266-e65b1"
# [1] "f1f101d2-3014-48cd-b54f-105ad"
# [1] "f6e4b397-267a-4fd8-9a3f-83a3b"
# [1] "f7d2f46e-94ed-41d4-beb8-4fbc9"
# [1] "ff0f6317-8a50-442c-91f5-5644f"

# %%
library(readxl)

# %%
write_xlsx(rhythm_df_sheets, paste0(loc_save_file, dataset, '_', data_name,'.xlsx')) # REMINDER: if you use personalized dominant period, change period_in_hour
# Out:
# Warning message in write_xlsx(rhythm_df_sheets, paste0(loc_save_file, dataset, "_", :
# "Truncating sheet name(s) to 31 characters"

# %%
newdata <- subset(df, subset=c((Timestamp > start_date) & (Timestamp < end_date)))
print(newdata)
# Out:
#                 Timestamp HeartRatePPG
#    1: 2020-02-04 21:35:49           80
#    2: 2020-02-04 21:35:54           79
#    3: 2020-02-04 21:35:59           77
#    4: 2020-02-04 21:36:04           76
#    5: 2020-02-04 21:36:09           75
#   ---
# 8812: 2020-02-06 21:35:09           79
# 8813: 2020-02-06 21:35:14           80
# 8814: 2020-02-06 21:35:19           81
# 8815: 2020-02-06 21:35:24           83
# 8816: 2020-02-06 21:35:29           82
